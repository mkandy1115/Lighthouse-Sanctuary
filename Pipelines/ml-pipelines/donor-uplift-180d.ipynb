# %% [markdown]
# # Donor Uplift 180d
#
# ## Problem Framing
# Predict donor uplift potential over a 180-day horizon to prioritize campaign targeting.
#
# ## Data Acquisition, Preparation & Exploration
# Pipeline implementation: `ML_Pipeline_4/run_pipeline.py`, `ML_Pipeline_4/src/features.py`, `ML_Pipeline_4/src/modeling.py`.
#
# ## Modeling & Feature Selection
# Predictive and explanatory variants are trained and combined into supporter-level uplift scoring.
#
# ## Evaluation & Interpretation
# Evaluation metrics support production model choice and donor outreach strategy.
#
# ## Causal and Relationship Analysis
# Relationship interpretation is included with explicit caution against over-claiming causality.
#
# ## Deployment Notes
# Integrated by ML refresh and surfaced in backend insights endpoints for staff usage.
