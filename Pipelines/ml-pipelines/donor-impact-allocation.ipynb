# %% [markdown]
# # Donor Impact Allocation
#
# ## Problem Framing
# Predict likely impact allocation patterns by donor to improve personalization and donor impact reporting.
#
# ## Data Acquisition, Preparation & Exploration
# Pipeline implementation: `ML_Pipeline_5/run_pipeline.py`, `ML_Pipeline_5/src/features.py`, `ML_Pipeline_5/src/modeling.py`.
#
# ## Modeling & Feature Selection
# Pipeline combines top-area prediction with explanatory education-share modeling.
#
# ## Evaluation & Interpretation
# Evaluation informs trustworthy donor-facing and staff-facing impact insights.
#
# ## Causal and Relationship Analysis
# Important feature relationships are discussed with clear limits on causal inference.
#
# ## Deployment Notes
# Served through `backend/Controllers/DonorController.cs` and refreshed via `backend/Services/MlScoringService.cs`.
